# %% [markdown]
# <a href="https://colab.research.google.com/github/r2x4/ETL_alura_oracle/blob/main/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Numpy: Análisis numérico eficiente con Python**

# %% [markdown]
# NumPy es una biblioteca de Python que ofrece diversas herramientas y funcionalidades esenciales para la computación científica, incluyendo objetos de matriz multidimensional conocidos como *arrays*, rutinas para operaciones rápidas en matrizes, además de operaciones matemáticas, manipulación de formas, estadística entre otros. Es ampliamente utilizada en áreas como análisis de datos, procesamiento de señales y aprendizaje de máquina.
#
# Para acceder a la documentación de esta biblioteca, puedes hacer clic en el siguiente enlace: https://numpy.org/devdocs/index.html

# %%
### llamar desde la pc el archivo

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dd76c096-7e86-4172-bc2a-60485a1549be" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dd76c096-7e86-4172-bc2a-60485a1549be">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np

datos = np.loadtxt('manzanas.csv', delimiter=',', usecols=np.arange(1, 88, 1))

print(datos.shape)
print(datos[:5])
# Out:
# (6, 87)
# [[  1.2013   2.2013   3.2013   4.2013   5.2013   6.2013   7.2013   8.2013
#     9.2013  10.2013  11.2013  12.2013   1.2014   2.2014   3.2014   4.2014
#     5.2014   6.2014   7.2014   8.2014   9.2014  10.2014  11.2014  12.2014
#     1.2015   2.2015   3.2015   4.2015   5.2015   6.2015   7.2015   8.2015
#     9.2015  10.2015  11.2015  12.2015   1.2016   2.2016   3.2016   4.2016
#     5.2016   6.2016   7.2016   8.2016   9.2016  10.2016  11.2016  12.2016
#     1.2017   2.2017   3.2017   4.2017   5.2017   6.2017   7.2017   8.2017
#     9.2017  10.2017  11.2017  12.2017   1.2018   2.2018   3.2018   4.2018
#     5.2018   6.2018   7.2018   8.2018   9.2018  10.2018  11.2018  12.2018
#     1.2019   2.2019   3.2019   4.2019   5.2019   6.2019   7.2019   8.2019
#     9.2019  10.2019  11.2019  12.2019   1.202    2.202    3.202 ]
#  [ 79.72    81.08    79.68    79.8     80.63    80.8     80.28    78.99
#    76.77    76.09    76.36    77.16    77.5     79.03    80.28    80.05
# ...

# %%
### importarlo desde la url

import numpy as np


url = 'https://gist.githubusercontent.com/ahcamachod/41b8a65c5e5b58125401deafb68af460/raw/f84320f69efa1cc3e86e1db054422cfa4869c63e/manzanas.csv'

np.loadtxt(url, delimiter=',',usecols = np.arange(1,88,1))
# Out:
# array([[  1.2013,   2.2013,   3.2013,   4.2013,   5.2013,   6.2013,
#           7.2013,   8.2013,   9.2013,  10.2013,  11.2013,  12.2013,
#           1.2014,   2.2014,   3.2014,   4.2014,   5.2014,   6.2014,
#           7.2014,   8.2014,   9.2014,  10.2014,  11.2014,  12.2014,
#           1.2015,   2.2015,   3.2015,   4.2015,   5.2015,   6.2015,
#           7.2015,   8.2015,   9.2015,  10.2015,  11.2015,  12.2015,
#           1.2016,   2.2016,   3.2016,   4.2016,   5.2016,   6.2016,
#           7.2016,   8.2016,   9.2016,  10.2016,  11.2016,  12.2016,
#           1.2017,   2.2017,   3.2017,   4.2017,   5.2017,   6.2017,
#           7.2017,   8.2017,   9.2017,  10.2017,  11.2017,  12.2017,
#           1.2018,   2.2018,   3.2018,   4.2018,   5.2018,   6.2018,
#           7.2018,   8.2018,   9.2018,  10.2018,  11.2018,  12.2018,
#           1.2019,   2.2019,   3.2019,   4.2019,   5.2019,   6.2019,
#           7.2019,   8.2019,   9.2019,  10.2019,  11.2019,  12.2019,
# ...

# %% [markdown]
# # Metodos basicos para explorar arrays

# %%
datos.ndim
# Out:
# 2

# %%
datos.shape
# Out:
# (6, 87)

# %%
datos
# Out:
# array([[  1.2013,   2.2013,   3.2013,   4.2013,   5.2013,   6.2013,
#           7.2013,   8.2013,   9.2013,  10.2013,  11.2013,  12.2013,
#           1.2014,   2.2014,   3.2014,   4.2014,   5.2014,   6.2014,
#           7.2014,   8.2014,   9.2014,  10.2014,  11.2014,  12.2014,
#           1.2015,   2.2015,   3.2015,   4.2015,   5.2015,   6.2015,
#           7.2015,   8.2015,   9.2015,  10.2015,  11.2015,  12.2015,
#           1.2016,   2.2016,   3.2016,   4.2016,   5.2016,   6.2016,
#           7.2016,   8.2016,   9.2016,  10.2016,  11.2016,  12.2016,
#           1.2017,   2.2017,   3.2017,   4.2017,   5.2017,   6.2017,
#           7.2017,   8.2017,   9.2017,  10.2017,  11.2017,  12.2017,
#           1.2018,   2.2018,   3.2018,   4.2018,   5.2018,   6.2018,
#           7.2018,   8.2018,   9.2018,  10.2018,  11.2018,  12.2018,
#           1.2019,   2.2019,   3.2019,   4.2019,   5.2019,   6.2019,
#           7.2019,   8.2019,   9.2019,  10.2019,  11.2019,  12.2019,
# ...

# %%
# Se cambian filas por columnas

datos.T
# Out:
# array([[  1.2013,  79.72  ,  42.67  ,  62.55  ,  48.26  ,  71.25  ],
#        [  2.2013,  81.08  ,  44.37  ,  62.73  ,  51.01  ,  71.35  ],
#        [  3.2013,  79.68  ,  44.73  ,  63.43  ,  50.91  ,  70.9   ],
#        [  4.2013,  79.8   ,  46.75  ,  63.83  ,  53.94  ,  71.92  ],
#        [  5.2013,  80.63  ,      nan,      nan,  61.27  ,  72.91  ],
#        [  6.2013,  80.8   ,  51.59  ,  69.22  ,  65.44  ,  74.39  ],
#        [  7.2013,  80.28  ,  57.8   ,  72.07  ,  56.51  ,  73.1   ],
#        [  8.2013,  78.99  ,  62.14  ,  69.31  ,  53.    ,  70.24  ],
#        [  9.2013,  76.77  ,  56.76  ,  65.18  ,  43.87  ,  69.12  ],
#        [ 10.2013,  76.09  ,  50.85  ,  62.13  ,  42.12  ,  68.98  ],
#        [ 11.2013,  76.36  ,  46.43  ,  64.17  ,  43.98  ,  68.58  ],
#        [ 12.2013,  77.16  ,  46.73  ,  65.5   ,  44.66  ,  69.5   ],
#        [  1.2014,  77.5   ,  45.85  ,  66.85  ,  47.73  ,  70.14  ],
#        [  2.2014,  79.03  ,  49.25  ,  68.38  ,  52.31  ,  70.58  ],
# ...

# %%
# variable para guardasr los datos transpuestos

datos_transpuestos = datos.T

# %% [markdown]
# # Visualizacion y Seleccion

# %%
# variables de fechas

fechas = datos_transpuestos[:,0]
fechas
# Out:
# array([ 1.2013,  2.2013,  3.2013,  4.2013,  5.2013,  6.2013,  7.2013,
#         8.2013,  9.2013, 10.2013, 11.2013, 12.2013,  1.2014,  2.2014,
#         3.2014,  4.2014,  5.2014,  6.2014,  7.2014,  8.2014,  9.2014,
#        10.2014, 11.2014, 12.2014,  1.2015,  2.2015,  3.2015,  4.2015,
#         5.2015,  6.2015,  7.2015,  8.2015,  9.2015, 10.2015, 11.2015,
#        12.2015,  1.2016,  2.2016,  3.2016,  4.2016,  5.2016,  6.2016,
#         7.2016,  8.2016,  9.2016, 10.2016, 11.2016, 12.2016,  1.2017,
#         2.2017,  3.2017,  4.2017,  5.2017,  6.2017,  7.2017,  8.2017,
#         9.2017, 10.2017, 11.2017, 12.2017,  1.2018,  2.2018,  3.2018,
#         4.2018,  5.2018,  6.2018,  7.2018,  8.2018,  9.2018, 10.2018,
#        11.2018, 12.2018,  1.2019,  2.2019,  3.2019,  4.2019,  5.2019,
#         6.2019,  7.2019,  8.2019,  9.2019, 10.2019, 11.2019, 12.2019,
#         1.202 ,  2.202 ,  3.202 ])

# %%
# variables de precios

precios = datos_transpuestos[:,1:]
precios
# Out:
# array([[ 79.72,  42.67,  62.55,  48.26,  71.25],
#        [ 81.08,  44.37,  62.73,  51.01,  71.35],
#        [ 79.68,  44.73,  63.43,  50.91,  70.9 ],
#        [ 79.8 ,  46.75,  63.83,  53.94,  71.92],
#        [ 80.63,    nan,    nan,  61.27,  72.91],
#        [ 80.8 ,  51.59,  69.22,  65.44,  74.39],
#        [ 80.28,  57.8 ,  72.07,  56.51,  73.1 ],
#        [ 78.99,  62.14,  69.31,  53.  ,  70.24],
#        [ 76.77,  56.76,  65.18,  43.87,  69.12],
#        [ 76.09,  50.85,  62.13,  42.12,  68.98],
#        [ 76.36,  46.43,  64.17,  43.98,  68.58],
#        [ 77.16,  46.73,  65.5 ,  44.66,  69.5 ],
#        [ 77.5 ,  45.85,  66.85,  47.73,  70.14],
#        [ 79.03,  49.25,  68.38,  52.31,  70.58],
#        [ 80.28,  48.14,  68.77,  56.8 ,  70.78],
#        [ 80.05,  49.18,  69.32,  51.15,  72.78],
#        [ 78.11,  49.49,  69.77,  54.63,  72.84],
#        [ 76.9 ,  49.83,  70.17,  55.8 ,  74.74],
#        [ 77.68,  49.14,  70.76,  57.31,  76.43],
# ...

# %%
# se importa para graficar

import matplotlib.pyplot as plt

plt.plot(fechas,precios)

# %%
# Solo graficamos una ciudad

import matplotlib.pyplot as plt

plt.plot(fechas,precios[:,0])

# %%
# organizar fechas del primer pais de los 7 anos


fechas = np.arange(1,88,1)

# %%
# Solo graficamos una ciudad

import matplotlib.pyplot as plt

plt.plot(fechas,precios[:,0])

# %%
# crear las variables de las ciudades

Moscu = precios[:,0]
Kaliningrado = precios[:,1]
Petersburgo = precios[:,2]
Krasnodar = precios[:,3]
Ekaterimburgo = precios[:,4]

# %%
plt.plot(fechas,Moscu)

# %%
plt.plot(fechas,Petersburgo)

# %%
plt.plot(fechas,Kaliningrado)

# %%
plt.plot(fechas,Krasnodar)

# %%
plt.plot(fechas,Ekaterimburgo)

# %% [markdown]
# # Comparacion de arrays

# %%
Moscu.shape
# Out:
# (87,)

# %%
moscu_1 = Moscu[0:12]
moscu_2 = Moscu[12:24]
moscu_3 = Moscu[24:36]
moscu_4 = Moscu[36:48]

# %%
# forma der ver por anos

#plt.plot(moscu_1)

plt.plot(np.arange(1,13,1),moscu_1)
plt.plot(np.arange(1,13,1),moscu_2)
plt.plot(np.arange(1,13,1),moscu_3)
plt.plot(np.arange(1,13,1),moscu_4)
plt.legend(['2013','2014','2015','2016'])

# %%
np.array_equal(moscu_1,moscu_2)
# Out:
# False

# %%
np.allclose(moscu_1,moscu_2, 2)
# Out:
# True

# %% [markdown]
# # Tratamiento NaN

# %%
np.mean(Moscu)
# Out:
# np.float64(98.79781609195402)

# %%
np.mean(Kaliningrado)
# Out:
# np.float64(nan)

# %%
plt.plot(fechas,Kaliningrado)

# %%
Kaliningrado
# Out:
# array([ 42.67,  44.37,  44.73,  46.75,    nan,  51.59,  57.8 ,  62.14,
#         56.76,  50.85,  46.43,  46.73,  45.85,  49.25,  48.14,  49.18,
#         49.49,  49.83,  49.14,  63.21,  61.2 ,  60.34,  62.2 ,  74.2 ,
#         75.32,  75.92,  72.89,  74.85,  92.19,  99.7 , 102.78,  92.67,
#         90.63,  83.31,  75.5 ,  74.6 ,  76.94,  83.04,  80.74,  80.29,
#         82.82,  86.29,  87.41,  85.1 ,  78.08,  76.06,  69.23,  69.04,
#         64.48,  65.73,  67.2 ,  70.25,  82.59,  92.12, 100.82,  95.23,
#         89.51,  82.84,  82.3 ,  83.76,  84.72,  83.91,  99.14, 101.6 ,
#        113.03, 119.54, 118.09, 107.32,  82.6 ,  77.4 ,  71.77,  71.25,
#         71.35,  73.62,  76.2 ,  74.15,  75.67,  79.2 ,  80.85,  85.33,
#         75.02,  77.95,  78.98,  76.55,  74.89,  70.  ,  81.53])

# %%
# aqui veremos el verdadero que es 1
# esto es interpolacion

np.isnan(Kaliningrado)
# Out:
# array([False, False, False, False,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False])

# %%
# aqui veremos que hay un verdadero osea un NaN

np.sum(np.isnan(Kaliningrado))
# Out:
# np.int64(1)

# %%
# se promedia el NaN entre los dos esto es interpolacion

Kaliningrado[4] = (Kaliningrado[3] + Kaliningrado[5])/2
Kaliningrado[4]
# Out:
# np.float64(49.17)

# %%
# aqui ya aparecera 0 osea false ya no hay datos NaN

np.sum(np.isnan(Kaliningrado))
# Out:
# np.int64(0)

# %%
plt.plot(fechas,Kaliningrado)

# %%
np.mean(Kaliningrado)
# Out:
# np.float64(74.5506896551724)

# %% [markdown]
# # Diferencia entre arrays

# %%
plt.plot(fechas,Moscu)

# %% [markdown]
# ### **y = ax + b**

# %%
# el 1.5 es un valor de crecimiento del precio de las manzans por mes es hipotetico

x = fechas
y = 1.5 * x + 78

# %%
y
# Out:
# array([ 79.5,  81. ,  82.5,  84. ,  85.5,  87. ,  88.5,  90. ,  91.5,
#         93. ,  94.5,  96. ,  97.5,  99. , 100.5, 102. , 103.5, 105. ,
#        106.5, 108. , 109.5, 111. , 112.5, 114. , 115.5, 117. , 118.5,
#        120. , 121.5, 123. , 124.5, 126. , 127.5, 129. , 130.5, 132. ,
#        133.5, 135. , 136.5, 138. , 139.5, 141. , 142.5, 144. , 145.5,
#        147. , 148.5, 150. , 151.5, 153. , 154.5, 156. , 157.5, 159. ,
#        160.5, 162. , 163.5, 165. , 166.5, 168. , 169.5, 171. , 172.5,
#        174. , 175.5, 177. , 178.5, 180. , 181.5, 183. , 184.5, 186. ,
#        187.5, 189. , 190.5, 192. , 193.5, 195. , 196.5, 198. , 199.5,
#        201. , 202.5, 204. , 205.5, 207. , 208.5])

# %%
plt.plot(fechas,Moscu)
plt.plot(x,y)

# %%
Moscu - y
# Out:
# array([ 2.2000e-01,  8.0000e-02, -2.8200e+00, -4.2000e+00, -4.8700e+00,
#        -6.2000e+00, -8.2200e+00, -1.1010e+01, -1.4730e+01, -1.6910e+01,
#        -1.8140e+01, -1.8840e+01, -2.0000e+01, -1.9970e+01, -2.0220e+01,
#        -2.1950e+01, -2.5390e+01, -2.8100e+01, -2.8820e+01, -3.1950e+01,
#        -3.3970e+01, -3.7610e+01, -3.4140e+01, -2.4840e+01, -1.0070e+01,
#        -1.2180e+01, -1.7350e+01, -2.1370e+01, -2.1540e+01, -2.5710e+01,
#        -2.5860e+01, -2.1740e+01, -2.4870e+01, -3.0360e+01, -3.3330e+01,
#        -3.3910e+01, -3.0430e+01, -2.4740e+01, -2.5660e+01, -2.5720e+01,
#        -2.8400e+01, -3.0940e+01, -2.8800e+01, -3.1120e+01, -4.3420e+01,
#        -5.1460e+01, -5.7170e+01, -6.0010e+01, -6.0060e+01, -5.9490e+01,
#        -6.0900e+01, -6.2220e+01, -5.8590e+01, -3.7240e+01, -3.0900e+01,
#        -3.4100e+01, -4.8950e+01, -6.3120e+01, -6.7410e+01, -6.4650e+01,
#        -6.2920e+01, -6.3000e+01, -5.7550e+01, -5.2830e+01, -5.3020e+01,
# ...

# %%
x = fechas
y = 0.5 * x + 78

# %%
plt.plot(fechas,Moscu)
plt.plot(x,y)

# %%
Moscu - y
# Out:
# array([  1.22,   2.08,   0.18,  -0.2 ,   0.13,  -0.2 ,  -1.22,  -3.01,
#         -5.73,  -6.91,  -7.14,  -6.84,  -7.  ,  -5.97,  -5.22,  -5.95,
#         -8.39, -10.1 ,  -9.82, -11.95, -12.97, -15.61, -11.14,  -0.84,
#         14.93,  13.82,   9.65,   6.63,   7.46,   4.29,   5.14,  10.26,
#          8.13,   3.64,   1.67,   2.09,   6.57,  13.26,  13.34,  14.28,
#         12.6 ,  11.06,  14.2 ,  12.88,   1.58,  -5.46, -10.17, -12.01,
#        -11.06,  -9.49,  -9.9 , -10.22,  -5.59,  16.76,  24.1 ,  21.9 ,
#          8.05,  -5.12,  -8.41,  -4.65,  -1.92,  -1.  ,   5.45,  11.17,
#         11.98,  16.58,  20.39,  17.36,  -8.24, -19.55, -20.57, -17.85,
#        -15.4 , -12.  , -12.19, -12.99,  -9.13,  -0.09,   7.79,   5.94,
#         -5.47, -16.81, -21.67, -18.93, -17.06, -12.77, -11.22])

# %%
# potenciar para buscar resultados

np.sum(np.power(Moscu - y,2))
# Out:
# np.float64(10718.7341)

# %%
# luego sacra raiz cuadrada

np.sqrt(np.sum(np.power(Moscu - y,2)))
# Out:
# np.float64(103.53131941591394)

# %%
# forma facil jajaja

np.linalg.norm(Moscu - y)
# Out:
# np.float64(103.53131941591394)

# %% [markdown]
# # Multiplicacion

# %%
n = np.size(Moscu)
y = Moscu
x = fechas

# %%
a = (n*np.sum(x*y)-np.sum(x)*np.sum(y))/(n*np.sum(x**2)-np.sum(x)**2)

# %%
b =  np.mean(y) - a*np.mean(x)

# %%
print(f'La pendientes es: {a}\nLa interseccion es: {b}')
# Out:
# La pendientes es: 0.43520212145512926
# La interseccion es: 79.64892274792834

# %%
y = a * x + b

# %%
y
# Out:
# array([ 80.08412487,  80.51932699,  80.95452911,  81.38973123,
#         81.82493336,  82.26013548,  82.6953376 ,  83.13053972,
#         83.56574184,  84.00094396,  84.43614608,  84.87134821,
#         85.30655033,  85.74175245,  86.17695457,  86.61215669,
#         87.04735881,  87.48256093,  87.91776306,  88.35296518,
#         88.7881673 ,  89.22336942,  89.65857154,  90.09377366,
#         90.52897578,  90.96417791,  91.39938003,  91.83458215,
#         92.26978427,  92.70498639,  93.14018851,  93.57539063,
#         94.01059276,  94.44579488,  94.880997  ,  95.31619912,
#         95.75140124,  96.18660336,  96.62180548,  97.05700761,
#         97.49220973,  97.92741185,  98.36261397,  98.79781609,
#         99.23301821,  99.66822033, 100.10342246, 100.53862458,
#        100.9738267 , 101.40902882, 101.84423094, 102.27943306,
#        102.71463519, 103.14983731, 103.58503943, 104.02024155,
#        104.45544367, 104.89064579, 105.32584791, 105.76105004,
# ...

# %%
np.linalg.norm(Moscu - y)
# Out:
# np.float64(101.7969539992751)

# %%
plt.plot(fechas,Moscu)
plt.plot(x,y)

# %%
# ver por un datos especifico aqui un mes

plt.plot(fechas,Moscu)
plt.plot(x,y)
plt.plot(25,a*25+b,'ro')
plt.plot(75,a*5+b,'ro')

# %%
# puntos de intreseccion valor
a*25+b
# Out:
# np.float64(90.52897578430657)

# %%
a*75+b
# Out:
# np.float64(112.28908185706302)

# %% [markdown]
# # Valores Aleatorios

# %%
# Entero

np.random.randint(40,100,100)
# Out:
# array([51, 58, 96, 80, 68, 84, 49, 75, 84, 41, 91, 69, 57, 78, 55, 76, 71,
#        82, 71, 75, 65, 43, 87, 92, 95, 52, 48, 91, 99, 54, 94, 46, 68, 51,
#        65, 93, 49, 65, 66, 63, 70, 79, 50, 98, 47, 60, 62, 76, 43, 72, 95,
#        81, 63, 69, 89, 95, 54, 82, 77, 63, 53, 72, 98, 61, 67, 56, 62, 41,
#        66, 82, 82, 74, 79, 67, 54, 46, 86, 69, 51, 86, 74, 65, 86, 46, 41,
#        71, 46, 89, 84, 72, 88, 89, 92, 62, 93, 46, 73, 78, 45, 60])

# %%
# Decimal

np.random.uniform(0.1,0.9,100)
# Out:
# array([0.49672426, 0.67781496, 0.1168481 , 0.84339887, 0.12487722,
#        0.58496562, 0.36078032, 0.62492726, 0.8462568 , 0.51015597,
#        0.11500699, 0.79619413, 0.2686635 , 0.49129965, 0.2859378 ,
#        0.77062753, 0.20731806, 0.88341222, 0.21654316, 0.32793106,
#        0.87094009, 0.27294545, 0.12951464, 0.71428554, 0.31706161,
#        0.45039917, 0.27816348, 0.78356457, 0.48621585, 0.87054345,
#        0.10045351, 0.81433021, 0.61568935, 0.60340426, 0.31220756,
#        0.50245918, 0.64057019, 0.23328454, 0.58604467, 0.13838587,
#        0.16575539, 0.14059539, 0.6158856 , 0.42258725, 0.33942832,
#        0.24670784, 0.2301391 , 0.50638328, 0.43264941, 0.62337858,
#        0.11431186, 0.79263961, 0.38992655, 0.87106603, 0.37582688,
#        0.41413311, 0.27398036, 0.72900573, 0.14474962, 0.72724118,
#        0.86597957, 0.2917798 , 0.75212878, 0.48033171, 0.79058563,
#        0.38420731, 0.14594043, 0.24543606, 0.33114064, 0.50922211,
# ...

# %%
pendientes = np.random.uniform(0.1,0.9,100)
pendientes
# Out:
# array([0.4484228 , 0.35428288, 0.71571451, 0.51678963, 0.76881785,
#        0.78743455, 0.14863408, 0.42574698, 0.49244723, 0.30147674,
#        0.28601684, 0.16741908, 0.83214012, 0.34318986, 0.86910938,
#        0.53516144, 0.22911962, 0.32066284, 0.37715494, 0.60384639,
#        0.64187986, 0.46646666, 0.37040491, 0.60823205, 0.32934218,
#        0.39305799, 0.70780254, 0.35881489, 0.13847293, 0.84077293,
#        0.75747479, 0.29681753, 0.28954438, 0.5180903 , 0.42858096,
#        0.19109475, 0.12992672, 0.32348   , 0.39129279, 0.14565588,
#        0.18671636, 0.45611509, 0.88937651, 0.81258087, 0.18392413,
#        0.30308525, 0.5503406 , 0.71448556, 0.70617746, 0.54211154,
#        0.62590055, 0.66232073, 0.24756493, 0.64184916, 0.48041454,
#        0.38932747, 0.39393682, 0.8463815 , 0.56623382, 0.8735614 ,
#        0.8726113 , 0.49781118, 0.13255067, 0.87352079, 0.47438139,
#        0.51310538, 0.79864243, 0.56928776, 0.89077207, 0.8425985 ,
# ...

# %%
# mejor valor

for i in range(100):
  print(np.linalg.norm(Moscu - (pendientes[i]*x + b)))
# Out:
# 101.98847794814905
# 108.74176384877086
# 167.13309436263228
# 108.85320946776898
# 187.65870027152235
# 195.10749083412432
# 169.41160975817965
# 101.89495958911718
# 105.32983617231595
# 119.81559708816825
# 123.824230454552
# 162.40370149347217
# 213.41442630526768
# 110.69387841405862
# 228.92038046649017
# 112.22211534001758
# 140.8764360293045
# 115.29157778451756
# 105.4278129255723
# 129.28058692756977
# 141.07101986575648
# 102.86344900049139
# 106.30232662794575
# 130.56828798210455
# 113.42395040734024
# 103.72670446320586
# 164.18362874614132
# 108.00730204832347
# 173.27373144401426
# 217.00856680761405
# 183.17883405446932
# 120.99124281999946
# 122.88284003660968
# 109.07241317258926
# 101.84502572989928
# 153.84638767560523
# 176.55773088926097
# 114.67263461386233
# 103.89008066076802
# 170.5386402879657
# 155.40372290614775
# 102.2755132818013
# 237.53670647303375
# 205.33832373804768
# 156.40307568547246
# 119.41646333000726
# 115.42477535386432
# ...

# %%
# crear la variable

norma = np.array([])

for i in range(100):
  norma = np.append(norma, np.linalg.norm(Moscu - (pendientes[i]*x + b)))

# %%
norma
# Out:
# array([101.98847795, 108.74176385, 167.13309436, 108.85320947,
#        187.65870027, 195.10749083, 169.41160976, 101.89495959,
#        105.32983617, 119.81559709, 123.82423045, 162.40370149,
#        213.41442631, 110.69387841, 228.92038047, 112.22211534,
#        140.87643603, 115.29157778, 105.42781293, 129.28058693,
#        141.07101987, 102.863449  , 106.30232663, 130.56828798,
#        113.42395041, 103.72670446, 164.18362875, 108.00730205,
#        173.27373144, 217.00856681, 183.17883405, 120.99124282,
#        122.88284004, 109.07241317, 101.84502573, 153.84638768,
#        176.55773089, 114.67263461, 103.89008066, 170.53864029,
#        155.40372291, 102.27551328, 237.53670647, 205.33832374,
#        156.40307569, 119.41646333, 115.42477535, 166.67288327,
#        163.58181666, 113.64354323, 135.95264999, 147.92252233,
#        134.99815693, 141.06097839, 104.01481339, 104.07954177,
#        103.64777248, 219.35270968, 119.14917483, 230.80661183,
# ...

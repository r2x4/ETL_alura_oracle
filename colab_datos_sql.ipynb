# %% [markdown]
# <a href="https://colab.research.google.com/github/r2x4/ETL_alura_oracle/blob/main/colab_datos_sql.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Datos SQL o bases de datos**

# %% [markdown]
# ### **crear un banco de Datos**

# %%
# importar biblioteca

import sqlalchemy

# %%
from sqlalchemy import create_engine, MetaData, Table, inspect, text, Column, Integer, String

# %% [markdown]
# # crear el banco de datos

# %%
# crear el motor de datos

engine = create_engine('sqlite:///:memory:')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e1f0e8f9-3185-457e-9404-da1f113d470a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e1f0e8f9-3185-457e-9404-da1f113d470a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Importar datos clientes Banco

import pandas as pd

datos_clientes = 'clientes_banco.csv'

# %%
# generar la variable para el banco

archivo = 'clientes_banco.csv'

# %%
# generar variable y leer la avriable del banco

datos = pd.read_csv(archivo)

# %%
datos.head()
# Out:
#    ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0     5008804    32    Nivel superior  Relación-estable               2
# 1     5008805    32    Nivel superior  Relación-estable               2
# 2     5008806    58  Nivel intermedio            Casado               2
# 3     5008808    52  Nivel intermedio           Soltero               1
# 4     5008809    52  Nivel intermedio           Soltero               1
#
#   Categoria_de_renta  Ocupacion  Años_empleado  Rendimiento_anual  \
# 0           Empleado       Otro             12           427500.0
# 1           Empleado       Otro             12           427500.0
# 2           Empleado  Seguridad              3           112500.0
# 3   Business Partner     Ventas              8           270000.0
# 4   Business Partner     Ventas              8           270000.0
#
#    Tiene_carro                  Vivienda
# 0            1    Departamento alquilado
# 1            1    Departamento alquilado
# ...

# %%
datos.tail()
# Out:
#         ID_Cliente  Edad     Grado_estudio Estado_civil  Tamaño_familia  \
# 438458     6840104    62  Nivel intermedio   Divorciado               1
# 438459     6840222    43  Nivel intermedio      Soltero               1
# 438460     6841878    22    Nivel superior      Soltero               1
# 438461     6842765    59  Nivel intermedio       Casado               2
# 438462     6842885    51  Nivel intermedio       Casado               2
#
#        Categoria_de_renta           Ocupacion  Años_empleado  \
# 438458        Pensionista                Otro              0
# 438459           Empleado  Construcción Civil              8
# 438460   Business Partner              Ventas              1
# 438461        Pensionista                Otro              0
# 438462           Empleado              Ventas              3
#
#         Rendimiento_anual  Tiene_carro                  Vivienda
# 438458           135000.0            0  Casa/Departamento propio
# ...

# %%
datos.sample(5)
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 356901     6481167    39    Nivel superior  Relación-estable               2
# 428555     7077676    29  Nivel intermedio            Casado               3
# 424916     7197081    52  Nivel intermedio            Casado               2
# 230646     5994130    38    Nivel superior        Divorciado               1
# 127236     6643547    52  Nivel intermedio            Casado               2
#
#        Categoria_de_renta           Ocupacion  Años_empleado  \
# 356901   Business Partner            Gerencia              9
# 428555           Empleado              Chofer              2
# 424916   Empleado estatal              Cocina              2
# 230646   Business Partner                Otro              3
# 127236           Empleado  Construcción Civil             32
#
#         Rendimiento_anual  Tiene_carro                  Vivienda
# 356901           436500.0            1  Casa/Departamento propio
# ...

# %%
type(datos)
# Out:
# pandas.core.frame.DataFrame

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438463 entries, 0 to 438462
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ID_Cliente          438463 non-null  int64
#  1   Edad                438463 non-null  int64
#  2   Grado_estudio       438463 non-null  object
#  3   Estado_civil        438463 non-null  object
#  4   Tamaño_familia      438463 non-null  int64
#  5   Categoria_de_renta  438463 non-null  object
#  6   Ocupacion           438463 non-null  object
#  7   Años_empleado       438463 non-null  int64
#  8   Rendimiento_anual   438463 non-null  float64
#  9   Tiene_carro         438463 non-null  int64
#  10  Vivienda            438463 non-null  object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 36.8+ MB

# %%
datos.shape
# Out:
# (438463, 11)

# %% [markdown]
# # llevarlo a sql

# %%
# crear tabla

datos.to_sql('clientes', engine, index=False)
# Out:
# 438463

# %%
# inspeccionar el sql

inspector = inspect(engine)

# %%
print(inspector.get_table_names())
# Out:
# ['clientes']

# %%
# Hacemos la Query

query = 'SELECT * FROM clientes WHERE categoria_de_renta = "Empleado"'

# %%
empleado = pd.read_sql(sql=text(query), con = engine.connect())

# %%
empleado
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008815    46    Nivel superior            Casado               2
# 4          5112956    46    Nivel superior            Casado               2
# ...            ...   ...               ...               ...             ...
# 226054     6837905    43  Nivel intermedio            Casado               3
# 226055     6837906    43  Nivel intermedio            Casado               3
# 226056     6839936    34  Nivel intermedio            Casado               3
# 226057     6840222    43  Nivel intermedio           Soltero               1
# 226058     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %% [markdown]
# # **Se guarda en una tabla SQL**

# %%
# exportar a SQL

empleado.to_sql('empleado', con = engine.connect(), index=False)
# Out:
# 226059

# %%
# ver la tablas de sql

pd.read_sql(sql=text('SELECT * FROM empleado'), con = engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008815    46    Nivel superior            Casado               2
# 4          5112956    46    Nivel superior            Casado               2
# ...            ...   ...               ...               ...             ...
# 226054     6837905    43  Nivel intermedio            Casado               3
# 226055     6837906    43  Nivel intermedio            Casado               3
# 226056     6839936    34  Nivel intermedio            Casado               3
# 226057     6840222    43  Nivel intermedio           Soltero               1
# 226058     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %%
# ver unas columnas de la  tabla de sql se llaman las columnas por texto o num.

pd.read_sql_table('empleado', con = engine.connect(), columns=[0,1,2,5,7])
# Out:
#         ID_Cliente  Edad     Grado_estudio Categoria_de_renta  Años_empleado
# 0          5008804    32    Nivel superior           Empleado             12
# 1          5008805    32    Nivel superior           Empleado             12
# 2          5008806    58  Nivel intermedio           Empleado              3
# 3          5008815    46    Nivel superior           Empleado              2
# 4          5112956    46    Nivel superior           Empleado              2
# ...            ...   ...               ...                ...            ...
# 226054     6837905    43  Nivel intermedio           Empleado              7
# 226055     6837906    43  Nivel intermedio           Empleado              7
# 226056     6839936    34  Nivel intermedio           Empleado              5
# 226057     6840222    43  Nivel intermedio           Empleado              8
# 226058     6842885    51  Nivel intermedio           Empleado              3
#
# [226059 rows x 5 columns]

# %% [markdown]
# # **Actualizando banco de datos**

# %%
# query

query = 'SELECT * FROM clientes'

# %%
# llamar base de datos y borra un cliente

pd.read_sql(sql=text(query), con = engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008815    46    Nivel superior            Casado               2
# 4          5112956    46    Nivel superior            Casado               2
# ...            ...   ...               ...               ...             ...
# 226054     6837905    43  Nivel intermedio            Casado               3
# 226055     6837906    43  Nivel intermedio            Casado               3
# 226056     6839936    34  Nivel intermedio            Casado               3
# 226057     6840222    43  Nivel intermedio           Soltero               1
# 226058     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %%
# borrar el registro se fue el cliente

from sqlalchemy.exc import SQLAlchemyError

query = 'DELETE FROM clientes WHERE ID_Cliente = 5008804'
try:
    r_set = engine.connect().execute(text(query))
except SQLAlchemyError as e:
    print(e)
else:
    print("Registro borrados: ", r_set.rowcount)
# Out:
# Registro borrados:  1

# %%
# volver la leer la tabla sql

pd.read_sql_table('clientes', con = engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008805    32    Nivel superior  Relación-estable               2
# 1          5008806    58  Nivel intermedio            Casado               2
# 2          5008808    52  Nivel intermedio           Soltero               1
# 3          5008809    52  Nivel intermedio           Soltero               1
# 4          5008810    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438457     6840104    62  Nivel intermedio        Divorciado               1
# 438458     6840222    43  Nivel intermedio           Soltero               1
# 438459     6841878    22    Nivel superior           Soltero               1
# 438460     6842765    59  Nivel intermedio            Casado               2
# 438461     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %% [markdown]
# # **Actualizar datos de un Cliente**

# %%
# Actualizar datos de un cliente

query = "UPDATE clientes SET Grado_estudio='Nivel superior' WHERE ID_Cliente = 5008808"
try:
    r_set = engine.connect().execute(text(query))
except SQLAlchemyError as e:
    print(e)
else:
    print("Registro actualizados: ", r_set.rowcount)
# Out:
# Registro actualizados:  1

# %%
# volver la leer la tabla sql

pd.read_sql_table('clientes', con = engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008805    32    Nivel superior  Relación-estable               2
# 1          5008806    58  Nivel intermedio            Casado               2
# 2          5008808    52    Nivel superior           Soltero               1
# 3          5008809    52  Nivel intermedio           Soltero               1
# 4          5008810    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438457     6840104    62  Nivel intermedio        Divorciado               1
# 438458     6840222    43  Nivel intermedio           Soltero               1
# 438459     6841878    22    Nivel superior           Soltero               1
# 438460     6842765    59  Nivel intermedio            Casado               2
# 438461     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %%
# inspeccionar el sql

inspector = inspect(engine)

# %%
print(inspector.get_table_names())
# Out:
# ['clientes', 'empleado']
